# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('/Users/colin/Desktop/projects/qcquant')
import qcquant_fitting as qcqf

# %%
x,d,_ = np.loadtxt('20240411_5.5H_2.2_ra.txt')

# qcqf.explore_line(x,d)

x_left = 5
x_right = 18

# %%
theta = qcqf.guess_growthexpansion(x,d,x_left,x_right)
qcqf.explore_growthexpansion(x,d,x_left,x_right,theta,x_max=40)
# Out:
# interactive(children=(FloatSlider(value=0.2263557668930058, description='k_g', max=2.0, min=0.01, step=0.001),…

# %%
success,theta = qcqf.fit_growthexpansion(x,d,x_left,x_right,theta,repeats=10,maxiters=1000,verbose=False)

fig,ax = qcqf.plot_growthexpansion(x,d,x_left,x_right,theta)

qcqf.format_report(theta,x,d,x_left,x_right)
# Out:
# $k_g$ = 0.308
# $k_c$ = 0.507
# $\sigma_{peak}$ = 2.181
# $k_d$ = 1.391
# $x_g$ = 9.152
# $x_d$ = 11.891
# $b$ = 0.150
# $\rho_g = 0.023$
